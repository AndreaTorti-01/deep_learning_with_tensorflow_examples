# %%
import os
from PIL import Image
import matplotlib.pyplot as plt

DATADIR = "PetImages"
CATEGORIES = ["Dog", "Cat"]

img_path = []

for category in CATEGORIES:  # do dogs and cats
    path = os.path.join(DATADIR,category)  # create path to dogs and cats
    for img in os.listdir(path):  # iterate over each image per dogs and cats
        img_path.append(os.path.join(path,img))  # add it to the list of all images

# %%
widths, heights = [], []
for img in img_path:
    try:
        width, height = Image.open(img).size
        widths.append(width)
        heights.append(height)
    except:
        print("Error: " + img)
# Out:
# /home/andre/Coding_WSL/deep_learning_with_tensorflow_examples/env/lib/python3.10/site-packages/PIL/TiffImagePlugin.py:858: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# Error: PetImages/Dog/Thumbs.db
# Error: PetImages/Dog/11702.jpg
# Error: PetImages/Cat/Thumbs.db
# Error: PetImages/Cat/666.jpg

# %%
plt.hist(widths, bins=200, range=(0, 1000))
plt.title("Widths")
plt.show()
plt.hist(heights, bins=20)
plt.title("Heights")
plt.show()
